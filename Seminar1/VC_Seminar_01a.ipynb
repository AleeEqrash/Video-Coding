# %% [markdown]
# ![](Picture2.png)

# %% [markdown]
# # <span style="color:navy"> Seminar 01 </span>: <span style="color:green"> <b>Audio Coding</b> </span>
# ### Prepared by <b> Dr. Imran </b>

# %% [markdown]
# ## <span style="color:navy"> <b>TASK:</b> Conversion of a Video to either R, G, or B </span>
#
# ### Introduction to the TASK
# In this assignment, you will learn:
# - How to convert an **RGB** video into purley **R**, **G** or **B** colors
# - How to get single color data from a 3D array of a frame of the given RGB Video.
#
# ### Description of TASK
# The task in this assignment is to use the given Video file named `videorec.mp4`, in the same directory as this jupyter notebook assignment file resides as your input Video File and convert this INPUT Video into *RED*, *GREEN* or *BLUE* **only**. The video file is a true RGB Video.
# <span style="color:navy"> Note: The file is automatically selected, you don not need to define it as input while working in the script </span>
#
# To start with the conversion of RGB video, update the given function (<span style="color:navy"> **def** </span> <span style="color:green"> **conversion():** </span>) to set or leave only one component such as *RED* or *GREEN* or *BLUE* (Reference to Lecture 2), while the others components should set to zero. (For example if you like to convert the input video to *RED*, select *GREEN=0* and *BLUE=0*)
#
# <span style="color:navy"> **Notes:** The assignment is randomly assigned according to the Matriculation (Mtr.) Number, therefore, insert your Mtr. Number into first cell and run this cell. Once you insert your Mrt. Number and execute the next cell, you will see in the printout which color you are asked to produce.</span>
#
# ### Exapected
# - In the Task, it is expected from students to complete the missing parts into the function, which is given in cell 3 with the name: <span style="color:navy"> **def** </span> <span style="color:green"> **conversion():** </span>. The function should write a video file with the name `output.mp4`.
# <span style="color:navy"> Note: The `output.mp4` file will be automatically saved, you don not need to define it as output while working in the script </span>
# - To complete the function (<span style="color:navy"> **def** </span> <span style="color:green"> **conversion():** </span>) given in cell-3, write your code below the commented line
# <span style="color:#239090">=BEGIN-SOLUTION=</span>
# and stop writting before the commented line
# <span style="color:#239090">=END-SOLUTION= </span>
# - <span style="color:red">Donot write your code before and after the mentioned lines and also DONOT delete these commented lines, otherwise you will fail the test. </span>
# - <span style="color:navy"> Note: Keep in mind that `OpenCV` package in python uses the order of color as "**BGR**", hence becarefull while using the converntions.</span>

# %% [markdown]
# ## <span style="color:green">Watch Given Input Video</span>
# ### <span style="color:navy">Run the cell below to watch Original Viedo.</span>

# %%
from IPython.display import Video
Video("videorec.mp4", height=400, embed=True)
# Out:
# <video controls   height="400">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # <span style="color:navy"> START Your Solution </span>
# ### <span style="color:navy"> Step I: Enter your Student ID (Matrikel Number)
# <span style="color:blue"> *NOTE: If you enter the wrong Matrikel Number you will fail the test.* </span>

# %%
student_id = "65624"

# YOUR CODE HERE
#raise NotImplementedError()

# %% [markdown]
# <span style="color:blue"> *Run the Cell Below to See YOUR Attendence* </span>

# %%
# Run the Cell

# %% [markdown]
# ### <span style="color:navy"> Step II: Execute the Cell Below </span>
# Now **RUN** the cell below in order to get which *Componente:* e.g. *RED* or *GREEN* or *BLUE* is asked to leave as it is. Which means the others remaining compnents must be set to zero.

# %%
import numpy as np
import scipy.signal as sp
import cv2

print("Your Student ID:  ",    student_id)
seed=0
for c in student_id:
    seed+=ord(c)
np.random.seed(seed)
r=np.random.rand()
if r<1.0/3:
    color='R'
elif(r<2.0/3):
    color='G'
else:
    color='B'
print("You are expected to convert the video to the color:   ", color)
# Out:
# Your Student ID:   65624
# You are expected to convert the video to the color:    G

# %% [markdown]
# ### <span style="color:navy"> Step III: Complete the Function </span>
# After you get the color name from above as **R**, **G** or **B**, write your script in the cell below under the function named as <span style="color:navy"> **def** </span> <span style="color:green"> **conversion():** </span>, according to the instructions
#
# <span style="color:red"> NOTE: Remove the ```raise NotImplementedError``` line otherwise you will fail the test. </span>

# %%
def conversion():
    cap = cv2.VideoCapture('videorec.mp4')
    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))   # float `width`
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print("width=", width, "height=", height)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    out = cv2.VideoWriter('output.mp4',fourcc, fps, (width,height))
    #out = cv2.VideoWriter('output.mp4',fourcc,20.0,(100,100))
    
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret==0:
            break
            
        # YOUR CODE HERE
        green_channel = np.zeros_like(frame)
        green_channel[:,:,1] = frame[:,:,1]
        
        #raise NotImplementedError()
        
        ### End Code here
        #
        out.write(green_channel)
    print("output.mp4 completed")
    cap.release()
    out.release()
    return

# %% [markdown]
# ### <span style="color:navy"> Step IV:  Execute the cell to evaluate your code </span>
# Once you have finished your function completion, execute the next cell below to evaluate your code and results

# %%
import scipy.signal as sp
import numpy as np
import matplotlib.pyplot as plt
import cv2

#conversion() #run submission
#print("Conversion done. Even if the Validade Notebook passes all tests that doesn't mean that your answer is correct!")
cap = cv2.VideoCapture('file_example.mp4')
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))   # float `width`
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print("width=", width, "height=", height)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = int(cap.get(cv2.CAP_PROP_FPS))
out = cv2.VideoWriter('output.mp4',fourcc, 20.0, (width,height))
#out = cv2.VideoWriter('output.mp4',fourcc, 20.0, (1280,720))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==0:
        break
        
    # YOUR CODE HERE
    green_channel = np.zeros_like(frame)
    green_channel[:,:,1] = frame[:,:,1]
    
    #raise NotImplementedError()
    
    ### End Code here
    #
    out.write(green_channel)
print("output.mp4 completed")
cap.release()
out.release()
# Out:
# width= 0 height= 0
# output.mp4 completed

# %% [markdown]
# ### <span style="color:navy">TASK Completed: </span> <span style="color:green"> **Good Luck** </span>

# %% [markdown]
# # <span style="color:red">Watch Results</span>

# %% [markdown]
# #### <span style="color:navy"> Fix the Problem </span>
# To watch the results fix problem in the cell below and GET **1** extra Points

# %%
import moviepy.editor as moviepy
clip = moviepy.VideoFileClip("output.mp4")
clip.write_videofile("outputtt.mp4")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\Alee Eqrash\AppData\Local\Programs\Python\Python310\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:285, in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     284 index = -1 if is_GIF else 0
# --> 285 line = [l for l in lines if keyword in l][index]
#     286 match = re.findall("([0-9][0-9]:[0-9][0-9]:[0-9][0-9].[0-9][0-9])", line)[0]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# e:\Study\Semester 4\Video Coding\Seminar1\VC_Seminar_01a.ipynb Cell 19 in 2
#       <a href='vscode-notebook-cell:/e%3A/Study/Semester%204/Video%20Coding/Seminar1/VC_Seminar_01a.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> import moviepy.editor as moviepy
# ...

# %%
from IPython.display import Video
Video("outputtt.mp4")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Study\Semester 4\Video Coding\Seminar1\VC_Seminar_01a.ipynb Cell 20 in 2
#       <a href='vscode-notebook-cell:/e%3A/Study/Semester%204/Video%20Coding/Seminar1/VC_Seminar_01a.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> from IPython.display import Video
# ----> <a href='vscode-notebook-cell:/e%3A/Study/Semester%204/Video%20Coding/Seminar1/VC_Seminar_01a.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> Video("outputtt.mp4")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\display.py:1162, in Video.__init__(self, data, url, filename, embed, mimetype, width, height, html_attributes)
#    1156 if data and not embed:
#    1157     msg = ''.join([
#    1158         "To embed videos, you must pass embed=True ",
#    1159         "(this may make your notebook files huge)\n",
#    1160         "Consider passing Video(url='...')",
# ...
